# %%
import pandas as pd

# %%
df = pd.read_excel("HelloFresh Business Case - International Product Operations Manager.xlsx")

# %%
df
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN                                             TASK 1
# 1          NaN  For Task 1, please answer to the questions below.
# 2          NaN                                                NaN
# 3          NaN  1A. What market assumptions can you make given...
# 4          NaN                                            Answer:
# ..         ...                                                ...
# 66         NaN                                        Preferences
# 67         NaN                                            Classic
# 68         NaN                                             Family
# 69         NaN                                         Vegetarian
# 70         NaN                                          Cal Smart
#
#                                            Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                                                 NaN        NaN        NaN
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10'],
#       dtype='object')
